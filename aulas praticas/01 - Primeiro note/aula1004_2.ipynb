# %% [markdown]
# Operadores lógicos

# %%
1 == 1 and 1 ==1
# Out:
# True

# %%
1 == 1 and 1 == 2
# Out:
# False

# %%
1 == False
# Out:
# False

# %%
1 != 0 and 1 ==1
# Out:
# True

# %%
0 == False
# Out:
# True

# %%
1 != 0
# Out:
# True

# %%
1 != 0 or 1 == 1
# Out:
# True

# %%
1 != 1 or 1 != 1
# Out:
# False

# %%
1 == 2 or 1 == 3
# Out:
# False

# %%
False and False and False
# Out:
# False

# %%
False and True and False
# Out:
# False

# %%
True and True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
# Out:
#   Cell In[23], line 1
#     p = 1 and p = 0
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
oi = [1, 2, 3, 4]
1 in oi
# Out:
# True

# %%
p = 1
q = p
q is p
# Out:
# True

# %%
p = 1
q = 1
p is q
# Out:
# True

# %%
p = 1
q = 1.0
p is q
# Out:
# False

# %%
p = 1
q = True
p is q
# Out:
# False

# %%
p = 1 
q = True
p == q
# Out:
# True

# %%
#calcula média dos index
df.mean(axis='index')
df.mean(axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.mean(axis='index')
#
# NameError: name 'df' is not defined

# %%
#calcula média das colunas 
f.mean(axis='colunas')
f.mean(axis='1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #calcula média das colunas
# ----> 2 f.mean(axis='colunas')
#       3 f.mean(axis='1')
#
# NameError: name 'f' is not defined

# %%
df.rename(
    columns={
        'a': 'A',
        'b': 'B',
        'c': 'C'
    },
    inplace=True
)

# %%
df.rename(
    columns={
        'a': 'A',
        'b': 'B',
        'c': 'C'
    },
    
)
