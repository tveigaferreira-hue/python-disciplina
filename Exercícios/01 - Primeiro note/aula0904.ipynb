# %%
import pandas as pd

# %%
import numpy as np

# %%
simbolo = [
    'IFNG',
    'Il10',
    'Tnf',
    'CSF2'
]
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = [
    'HGNC:HGNC:5438',
    'RGD:2886',
    'MGI:MGI:104798',
    'HGNC:HGNC:2434'
]
gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding'
]
organism = [
    'Homo sapiens',
    'Rattus norvegicus',
    'Mus musculus',
    'Homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'Il10', 'Tnf', 'CSF2'],
#  ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
# criar dicionario instanciando as chaves e utilizando as listas como valor
dicionariohoje = {
    "simbolo": simbolo,
    "full_name": full_name,
    "source": source,
    "gene_type": gene_type,
    "organism": organism,
    "chromosome": chromosome
    }
dicionariohoje
# Out:
# {'simbolo': ['IFNG', 'Il10', 'Tnf', 'CSF2'],
#  'full_name': ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  'source': ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  'gene_type': ['protein coding',
#   'protein coding',
#   'protein coding',
#   'protein coding'],
#  'organism': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
# juntar todas as listas em uma lista
gene_array = np.array(gene_matriz_lista)
gene_array
# Out:
# array([['IFNG', 'Il10', 'Tnf', 'CSF2'],
#        ['interferon gamma', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
# ver estrutura da tabela (6 linhas e 4 colunas)
gene_array.shape
# Out:
# (6, 4)

# %%
# pesquisar linha
gene_array[3]
# Out:
# array(['protein coding', 'protein coding', 'protein coding',
#        'protein coding'], dtype='<U27')

# %%
# pesquisar coluna
gene_array[:,0]
# Out:
# array(['IFNG', 'interferon gamma', 'HGNC:HGNC:5438', 'protein coding',
#        'Homo sapiens', '12'], dtype='<U27')

# %%
# ler linha e coluna específicos
gene_array[1, 3]
# Out:
# np.str_('colony stimulating factor 2')
