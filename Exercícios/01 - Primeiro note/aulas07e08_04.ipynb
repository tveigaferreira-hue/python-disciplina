# %% [markdown]
# Exercício 07/04

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import os

# %%
os.listdir()
# Out:
# ['exercício_python.ipynb', 'primeiro_note.ipynb']

# %%
object_str = 'This is a string object'
object_int = 42
object_str
# Out:
# 'This is a string object'

# %%
type(object_str)
# Out:
# str

# %%
obj_float = 4.2
"Python 'lindo'"
'Python "lindo"'
# Out:
# 'Python "lindo"'

# %%
def armario():
   print ("oiiii")

# %%
obj_float = 4.2
object_int = 42
object_str = "42"
object_bool = True

# %%
armario()
# Out:
# oiiii

# %%
help(armario)
# Out:
# Help on function armario in module __main__:
#
# armario()

# %%
dir(armario)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# Exercício 08/04

# %% [markdown]
# Instanciar é reservar um pedaço da memoria para armazenar a informação. Guardando toda a abstração do objeto.
# Vetores: objetos compostos com objetivo de organizar melhor as informações.
# Toda lista de objeto inicia em 0

# %%
lamps = [
    "ligada",
    "desligada",
    "desligada",
    "ligada",
]

# %% [markdown]
# Dicionarios em python utiliza chave {} e "chaves".

# %%
objs_simples = {
    "index1": "valor1",
    "nome" : "CPF",
}

# %% [markdown]
# Tupla: () Auto indexado imutável
# Lista [] Auto indexado mutável
# Dicionario: {} Indexação manual mutável
# Set: {} conjunto sem chave interna, subscreve se repetir valores. Não indexavel imutável
# Array: Numpy
# Data frame: Panda

# %% [markdown]
# Indexação independente do objeto, usa colchetes.

# %% [markdown]
# Prática

# %%
tupla = ("arroz", "feijao", "carne", "macarrao")
tupla
# Out:
# ('arroz', 'feijao', 'carne', 'macarrao')

# %%
type(tupla)
# Out:
# tuple

# %%
lista = ["gato", "cachorro", "vaca", "galo"]
lista
# Out:
# ['gato', 'cachorro', 'vaca', 'galo']

# %%
dicionario = {"boi": "mamífero", "galinha": "ave", "sapo": "anfibio"}
dicionario
# Out:
# {'boi': 'mamífero', 'galinha': 'ave', 'sapo': 'anfibio'}

# %%
tupla[2]
# Out:
# 'carne'

# %%
tupla[-1]
# Out:
# 'macarrao'

# %%
lista[:2]
# Out:
# ['gato', 'cachorro']

# %%
dicionario['galinha']
# Out:
# 'ave'

# %%
lista.append('tatu')

# %%
lista
# Out:
# ['gato', 'cachorro', 'vaca', 'galo', 'tatu']

# %%
dicionario["tilapia"] = "peixe"
dicionario
# Out:
# {'boi': 'mamífero', 'galinha': 'ave', 'sapo': 'anfibio', 'tilapia': 'peixe'}

# %%
lista.pop()
lista
# Out:
# ['gato', 'cachorro', 'vaca', 'galo']

# %%
ave = lista[3]
ave
# Out:
# 'galo'

# %%
a, b, *d = lista
print(a, b, d)
# Out:
# gato cachorro ['vaca', 'galo']

# %% [markdown]
# Objetos compostos multidimensionais: primeiro linha e depois coluna.

# %% [markdown]
# Bibliotecas:
# SciPy
# Pandas
# Numpy

# %%
import pandas as pd
import numpy as np

# %%
array.shape 
numero de linhas e colunas
